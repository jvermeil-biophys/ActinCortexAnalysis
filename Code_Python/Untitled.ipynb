# %%
import pandas as pd
import numpy as np
import os

mainDir = "C://Users//JosephVermeil//Desktop//ActiveFluctuationDataset"
dirTraj = os.path.join(mainDir, 'Trajectories')
dirDist = os.path.join(mainDir, 'Distances')

# %%
fList = [f for f in os.listdir(dirDist) if (os.path.isfile(os.path.join(dirDist, f)) and f.endswith(".csv"))]

for f in fList:
    cellId = f[:17]
    fPath = os.path.join(dirDist, f)
    df = pd.read_csv(fPath, sep = ';', header = 0)
    
    fList2 = [f for f in os.listdir(dirDist) if (os.path.isfile(os.path.join(dirDist, f)) and f.endswith(".csv"))]

# %%
df
# Out:
#      idxAnalysis        T       Tabs        B           F        dx        dy  \
# 0              0    0.681  19297.337  5.75345  132.218331  4.557215  1.026139
# 1              0    1.281  19297.937  5.75460  131.968355  4.555253  1.035127
# 2              0    1.881  19298.537  5.75345  131.238967  4.552405  1.050190
# 3              0    2.481  19299.137  5.75345  131.462037  4.553924  1.050823
# 4              0    3.081  19299.737  5.75345  132.727158  4.553861  1.022785
# ..           ...      ...        ...      ...         ...       ...       ...
# 589            0  395.614  19692.270  5.75345   47.782893  4.593291  1.682532
# 590            0  396.215  19692.871  5.75460   47.746685  4.564051  1.712785
# 591            0  396.814  19693.470  5.75345   47.169850  4.537595  1.765127
# 592            0  397.414  19694.070  5.75345   46.641904  4.522152  1.800823
# 593            0  398.015  19694.671  5.75460   46.680600  4.509051  1.807089
#
#           dz        D2        D3
# 0    0.14875  4.671314  4.673681
# 1    0.16450  4.671383  4.674278
# 2    0.20825  4.671969  4.676608
# 3    0.15400  4.673591  4.676128
# 4    0.14525  4.667305  4.669565
# ..       ...       ...       ...
# 589  2.35725  4.891752  5.430089
# 590  2.35550  4.874853  5.414108
# 591  2.35375  4.868823  5.407918
# 592  2.35550  4.867527  5.407513
# 593  2.35725  4.857685  5.399420
#
# [594 rows x 10 columns]
